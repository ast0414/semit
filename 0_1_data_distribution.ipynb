# %%
# %matplotlib inline

# %%
import pickle
import matplotlib.pyplot as plt # plotting
import seaborn as sns
import numpy as np # linear algebra

# %%
plt.style.use("dark_background")

# %% [markdown]
# # MNIST

# %%
with open("data/mnist_full.pkl", 'rb') as f:
    mnist = pickle.load(f)

# %%
sns.countplot(mnist['y_train'])
plt.xlabel('class', size=20)
plt.ylabel('count', size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000., 7000.]),
#  <a list of 8 Text yticklabel objects>)

# %%
sns.countplot(mnist['y_val'])
plt.xlabel('class', size=20)
plt.ylabel('count', size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text yticklabel objects>)

# %%
sns.countplot(mnist['y_test'])
plt.xlabel('class', size=20)
plt.ylabel('count', size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  <a list of 7 Text yticklabel objects>)

# %% [markdown]
# # Kannada-MNIST

# %%
with open("data/kannada_semi_1pct.pkl", 'rb') as f:
    kannada = pickle.load(f)

# %%
np.concatenate((kannada['y_train_labeled'], kannada['y_train_unlabeled'])).shape
# Out:
# (55000,)

# %%
sns.countplot(np.concatenate((kannada['y_train_labeled'], kannada['y_train_unlabeled'])))
plt.xlabel('class', size=20)
plt.ylabel('count', size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000.]),
#  <a list of 7 Text yticklabel objects>)

# %%
sns.countplot(kannada['y_val'])
plt.xlabel('class', size=20)
plt.ylabel('count', size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text yticklabel objects>)

# %%
sns.countplot(kannada['y_test'])
plt.xlabel('class', size=20)
plt.ylabel('count', size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  <a list of 7 Text yticklabel objects>)
